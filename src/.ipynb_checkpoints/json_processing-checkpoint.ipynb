# %%
import numpy as np
import pandas as pd
import json

# %%
f = open('report.json')
data = json.load(f)

# %%
for i in range(len(data['report'][2])):
    for j in range(len(data['report'][2])):
        if data['report'][2][i][0] == data['report'][2][j][0]:
            print(data['report'][2][j])
# Out:
# ['rcc-curated-default-01-daily', 2, '2022-11-07T15:02+01:00', '', '2022-11-07']
# ['rcc-curated-default-01-daily', 1, '2022-11-11T15:06+01:00', '', '2022-11-11']
# ['rcc-curated-default-01-daily', 2, '2022-11-13T08:55+01:00', '', '2022-11-13']
# ['rcc-curated-default-01-daily', 3, '2022-11-17T20:07+01:00', '', '2022-11-17']
# ['rcc-curated-default-01-daily', 1, '2022-11-18T09:04+01:00', '', '2022-11-18']
# ['rcc-curated-default-01-daily', 0, '2022-11-23T08:32+01:00', '', '2022-11-23']
# ['rcc-curated-default-01-daily', 1, '2022-11-25T12:46+01:00', '', '2022-11-25']
# ['rcc-curated-default-02-daily', 1, '2022-11-07T15:03+01:00', '', '2022-11-07']
# ['rcc-curated-default-02-daily', 1, '2022-11-11T15:06+01:00', '', '2022-11-11']
# ['rcc-curated-default-02-daily', 1, '2022-11-13T08:56+01:00', '', '2022-11-13']
# ['rcc-curated-default-02-daily', 1, '2022-11-17T20:07+01:00', '', '2022-11-17']
# ['rcc-curated-default-02-daily', 3, '2022-11-18T09:04+01:00', '', '2022-11-18']
# ...

# %%
print(data["report"][0])
# Out:
# None

# %%
print(data["report"][1])
# Out:
# 2022-11-28T20:23:46.926Z
